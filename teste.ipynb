# %%
import numpy
import sys

sys.path.append('lib/')
from myAudioProcessingLib import *

# %%
SOUND_PATH = 'sounds/'

SOUND_FILE = 'train.wav'

# %%
x, fs = audioread(SOUND_PATH + SOUND_FILE)
play(x, fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np

def media_movel(signal, window_size):
    weights = np.repeat(1.0, window_size) / window_size
    moving_average = np.convolve(signal, weights, mode='same')

    return moving_average


teste = media_movel(x, 2048)

play(teste, fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from scipy.signal import savgol_filter


# Especificação dos parâmetros do filtro
window_length = 50  # Tamanho da janela
polyorder = 2      # Ordem do polinômio

# Aplicando o filtro Savitzky-Golay
smoothed_data = savgol_filter(x, window_length, polyorder)

play(smoothed_data, fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
