# %%
import numpy
import sys

sys.path.append('lib/')
from myAudioProcessingLib import *

# %%
SOUND_PATH = 'sounds/'

SOUND_FILE = 'speech.wav'

# %%
x, fs = audioread(SOUND_PATH + SOUND_FILE)

# %%
# Magnitude
x
# Out:
# array([ 4.57770657e-05,  0.00000000e+00, -4.57770657e-05, ...,
#        -4.57770657e-05, -1.52590219e-05,  1.52590219e-05])

# %%
# Hz - frequências
fs
# Out:
# 16000

# %%
play(x, fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#transformada de fourier (DFT)
import numpy as np
import matplotlib.pyplot as plt

 
def dft(x):
    
    N = len(x)
    X = np.zeros(N, dtype=complex)

    for k in range(N):
        for n in range(N):
            X[k] += x[n]*np.exp(-1j * 2 * np.pi * n * k / N)
    
    return X

# %%
X = dft(x[:1000])

#transformada de fourier usando numpy
np.fft.fft(x)
# Out:
# array([  2.16803235-6.21724894e-15j,  -5.58027702-6.53290574e-01j,
#         -5.33978446-2.12090005e+00j, ..., -16.19446205+4.12416270e+00j,
#         -5.33978446+2.12090005e+00j,  -5.58027702+6.53290574e-01j])

# %%
import matplotlib.pyplot as plt
#gráfico de toda a magnetude do audio

np.fft.fft(x)

Xmag = np.abs(x)
plt.plot(Xmag)

# %%
import matplotlib.pyplot as plt
Xmag = np.abs(X)
plt.plot(Xmag)

# %%
def dft1(x):
    
    N = len(x)
    n = np.arange(N)
    
    X = np.zeros(N, dtype=complex)
    
    
    for k in np.arange(N):
        w = np.exp(-1j * (2 * np.pi / N) * k * n)
        
        #X[k] += np.inner(w.T, x)
        # ou 
        X[k] += w.T @ x
    
    return X

# %%
Y1 = dft1(x[:1000])

# %%
import matplotlib.pyplot as plt
Y1mag = np.abs(Y1)
plt.plot(Y1mag)

# %%
def dft2(x):
      
    N = len(x)

    n = np.expand_dims(np.arange(N), 1)
    
    W = np.exp(-1j * (2 * np.pi / N) * (n @ n.T))
        
    X =  W @ x
    
    return X

# %%
Y2 = dft2(x[:1000])

# %%
import matplotlib.pyplot as plt
Y2mag = np.abs(Y2)
plt.plot(Y2mag)

# %%
import numpy as np
import matplotlib.pyplot as plt
X = np.fft.fft(x)

X = np.abs(X)
plt.plot(X)
