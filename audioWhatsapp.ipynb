# %%
import numpy as np
import sys
sys.path.append('lib/')

from myAudioProcessingLib import *

# %%
SOUND_PATH = 'sounds/'

SOUND_FILE = 'speech.wav'


x, fs = audioread(SOUND_PATH + SOUND_FILE)

# %%
x
# Out:
# array([ 4.57770657e-05,  0.00000000e+00, -4.57770657e-05, ...,
#        -4.57770657e-05, -1.52590219e-05,  1.52590219e-05])

# %%
fs
# Out:
# 16000

# %%
play(x, fs/1)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import numpy as np
from scipy.io import wavfile
import matplotlib.pyplot as plt

# %%
sample_rate, audio_data = wavfile.read('materiais-main/sounds/train.wav')

# %%
audio_data = audio_data.astype(float) / 2**15
audio_data = audio_data[:, 0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\moura\Projetos\PDSI\audioWhatsapp.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/moura/Projetos/PDSI/audioWhatsapp.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> audio_data = audio_data.astype(float) / 2**15
# ----> <a href='vscode-notebook-cell:/c%3A/Users/moura/Projetos/PDSI/audioWhatsapp.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> audio_data = audio_data[:, 0]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
