# %% [markdown]
# Aula 29/09/2023

# %%
import math
import numpy as np

x = np.linspace(-10, 10, 5000)

np.sinc(x)
# Out:
# array([-3.89817183e-17, -4.00229606e-04, -8.00716465e-04, ...,
#        -8.00716465e-04, -4.00229606e-04, -3.89817183e-17])

# %%
import matplotlib.pyplot as plt

plt.stem(x, np.sinc(x))
# Out:
# <StemContainer object of 3 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0.0001, 10, 10000)

s = np.sin(t)/t

#n = np.linspace(0.0001, 10, 1000)

plt.plot(t, s)

# %%
n = t[0:-1:]
yn = y[0:-1:10]

plt.steam(n, yn)

.pltxlim([0,1])
